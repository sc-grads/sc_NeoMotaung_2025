# %%
d = {'key1' : 'value', 'key2': 'value2', 'key3': [1,2,3]}

# %%
d['key1']
# Out:
# 'value'

# %%
d['key3'][1]
# Out:
# 2

# %%
my_list = d['key3']

# %%
my_list[1]
# Out:
# 2

# %%
my_dict = {'k1': {'innerkey': [1,2,3]}}

# %%
my_dict['k1']['innerkey'][1]
# Out:
# 2

# %%
2 < 1
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
2 <= 2
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
1 != 1
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
(2==2) and (2 != 3)
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
if True:
    print('True')
# Out:
# True

# %%
if 1 == 2:
    print("first")
elif 4 == 4:
    print("Second")
else:
    print("last")
# Out:
# Second

# %%
list(range(0,5))
# Out:
# [0, 1, 2, 3, 4]

# %%
my_list = [1,2,3,4]
out = [num ** 2 for num in my_list]

# %%
out
# Out:
# [1, 4, 9, 16]

# %%
def func(name):
    """
    This is the docstring of a function
    Allows you to document further details about a function
    """
    print("Hello, " + name)

# %%
func("Neo")
# Out:
# Hello, Neo

# %%
"""
This is a multi line commend
These are comments with multiple lines
"""
# Out:
# '\nThis is a multi line commend\nThese are comments with multiple lines\n'

# %%
lambda num: num * 2
# Out:
# <function __main__.<lambda>(num)>

# %%
seq = [1,2,3,4,5]

# %%
map(times2, seq)

# %%
list(map(lambda num: num * 4, seq))
# Out:
# [4, 8, 12, 16, 20]

# %%
list(filter(lambda num: num % 2 == 0, seq))
# Out:
# [2, 4]

# %%
s = 'hello this is a string'

# %%
s.islower()
# Out:
# True

# %%
s.split()
# Out:
# ['hello', 'this', 'is', 'a', 'string']

# %%
1 in [2,3, 4]
# Out:
# False

# %%
'x' in ['x', 'y', 'z']
# Out:
# True

# %%
x = [(1,2), (3,4),(5,6)]
for (a,b) in x:
    print(a)
# Out:
# 1
# 3
# 5
