# %%
import chart_studio.plotly as py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import chart_studio.plotly as py
#
# ModuleNotFoundError: No module named 'chart_studio'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.24.1

# %%
import cufflinks as cf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import cufflinks as cf
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#cf.go_offline

# %%
df = pd.DataFrame(np.random.randn(100, 4), columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -0.625379  0.229223  0.100205 -2.220277
# 1  0.424981  0.493542  1.759626  0.031068
# 2 -1.518382 -0.759726 -0.002052 -0.699485
# 3  0.506431  0.914533  0.848321  0.743540
# 4 -1.490679 -0.976837 -1.142419 -0.347853

# %%
df2 = pd.DataFrame({'Category':['A','B','C'], 'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()
plt.show()

# %%
#df.iplot(kind='scatter', x='A', y='B', mode='markers')

# %%
#df.iplot(kind='bar', x='Category',y='Values')

# %%
#df.iplot(kind='bar') simply isnt just good enough on its own it needs some sort of aggregation

# %%
#Example:
#df.sum().iplot(kind='bar')

# %%
#df.iplot(kind='box')

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[10,20,30,40,50], 'z':[500,400,300,200,100]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  40  200
# 4  5  50  100

# %%
#df3.iplot(kind='surface')

# %%
#df3.iplot(kind='surface', colorscale='rdylbu')

# %%
#df['A'].iplot(kind='hist', bin=30)

# %%
#df[['A', 'B']].iplot(kind='spread')

# %%
#df.iplot(kind='bubble', x='A', y='B')

# %%
#df.scatter_matrix()
