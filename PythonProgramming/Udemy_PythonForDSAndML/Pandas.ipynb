# %%
import pandas as pd
import numpy as np

# %%
labels = ['a', 'b', 'c']
my_data = [10, 20, 30]
arr = np.array(my_data)
d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4], ['USA','Germany','USSR','Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,4,2,6], ['USA', 'Japan', 'Italy', 'Germany'])

# %%
ser2
# Out:
# USA        1
# Japan      4
# Italy      2
# Germany    6
# dtype: int64

# %%
ser1 + ser2
# Out:
# Germany    8.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4), ['A','B','C','D','E'], ['W','X','Y','Z'] )

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
#A data frame is a bunch of series that share the same index

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
df['new'] = df['W'] + df['Z']

# %%
df['new']
# Out:
# A    3.210676
# B    1.257083
# C   -2.607169
# D    1.143752
# E    0.874303
# Name: new, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.210676
# B  0.651118 -0.319318 -0.848077  0.605965  1.257083
# C -2.018168  0.740122  0.528813 -0.589001 -2.607169
# D  0.188695 -0.758872 -0.933237  0.955057  1.143752
# E  0.190794  1.978757  2.605967  0.683509  0.874303

# %%
df.drop('new', axis = 1, inplace = True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('E')
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.shape
# Out:
# (5, 4)

# %%
df[['W','X']]
# Out:
#           W         X
# A  2.706850  0.628133
# B  0.651118 -0.319318
# C -2.018168  0.740122
# D  0.188695 -0.758872
# E  0.190794  1.978757

# %%
df.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
#Rows are series as well

# %%
df.iloc[0]
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
#iloc gives numerical index

# %%
df.loc[['A', 'B'], ['W', 'Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df > 0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
booldf = df > 0

# %%
df[booldf]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W']>0
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: W, dtype: bool

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#No longer gives those null values, it just filters out the row with the null value instead

# %%
df[df['Z']< 0]
# Out:
#           W         X         Y         Z
# C -2.018168  0.740122  0.528813 -0.589001

# %%
df[df['W']>0][['X','Y']]
# Out:
#           X         Y
# A  0.628133  0.907969
# B -0.319318 -0.848077
# D -0.758872 -0.933237
# E  1.978757  2.605967

# %%
df[(df['W'] > 0) & (df['Y'] > 1)]
# Out:
#           W         X         Y         Z
# E  0.190794  1.978757  2.605967  0.683509

# %%
#Have to use symbolic logical operators, not just AND and OR because multiple conditions are being tested on the series(df[W] > 0) and then to the other ocndition (df[Y] > 1)

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
new_ind = 'CA NY WY OR CO'.split()

# %%
new_ind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['States'] = new_ind

# %%
df
# Out:
#           W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
#Would have to set inplace = true as a parameter to actually apply the change to the data frame,

# %%
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside, inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
outside
# Out:
# ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']

# %%
inside
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
#hier_index = list(zip(outside, inside))

# %%
list(zip(outside, inside))
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
#hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
pd.MultiIndex.from_tuples(hier_index)
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(randn(6,2), hier_index, ['A','B'])

# %%
df
# Out:
#              A         B
# G1 1  0.302665  1.693723
#    2 -1.706086 -1.159119
#    3 -0.134841  0.390528
# G2 1  0.166905  0.184502
#    2  0.807706  0.072960
#    3  0.638787  0.329646

# %%
df.loc['G1']
# Out:
#           A         B
# 1  0.302665  1.693723
# 2 -1.706086 -1.159119
# 3 -0.134841  0.390528

# %%
df.loc['G1'].loc[2]
# Out:
# A   -1.706086
# B   -1.159119
# Name: 2, dtype: float64

# %%
df.index.names = ['Groups', 'Num']

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1    0.302665  1.693723
#        2   -1.706086 -1.159119
#        3   -0.134841  0.390528
# G2     1    0.166905  0.184502
#        2    0.807706  0.072960
#        3    0.638787  0.329646

# %%
df.loc['G2'].loc[2]['B']
# Out:
# np.float64(0.07295967531703869)

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1    0.302665  1.693723
# 2   -1.706086 -1.159119
# 3   -0.134841  0.390528

# %%
df.xs(1, level='Num')
# Out:
#                A         B
# Groups
# G1      0.302665  1.693723
# G2      0.166905  0.184502

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1    0.302665  1.693723
#        2   -1.706086 -1.159119
#        3   -0.134841  0.390528
# G2     1    0.166905  0.184502
#        2    0.807706  0.072960
#        3    0.638787  0.329646

# %%
d = {'A':[1,2,np.nan],'B':[5, np.nan, np.nan], 'C':[1,2,3]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna() #drops rows with null values
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(axis=1) #drops columns with null values
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2) #only drops rows with at least 2 null values
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].fillna(value=df['A'].mean()) #Sets null values to the mean of the A column
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
byComp = df.groupby('Company')

# %%
byComp

# %%
byComp.mean('Sales')
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
byComp.sum('Sales').loc['FB']
# Out:
# Sales    593
# Name: FB, dtype: int64

# %%
df.groupby('Company').min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
df.groupby('Company').describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# col2
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
def times2(x):
    return x*2

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col2'].apply(lambda x:x*2)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df.drop('col1', axis=1)
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.sort_values('col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
import numpy as np

df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D', index=['A','B'], columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %%
df = pd.read_csv('C:/Users/Neo Motaung/Downloads/Py_DS_ML_Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/03-Python-for-Data-Analysis-Pandas/example')

# %%
df.to_csv('my_output', index=False)

# %%
pd.read_csv('my_output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('C:/Users/Neo Motaung/Downloads/Py_DS_ML_Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/03-Python-for-Data-Analysis-Pandas/Excel_Sample.xlsx')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel('excel_sample2.xlsx', sheet_name='newSheet')

# %%
pd.read_excel('excel_sample2.xlsx', sheet_name='newSheet')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df
# Out:
# [                                            Bank Name                City  \
#  0                        The Santa Anna National Bank          Santa Anna
#  1                                Pulaski Savings Bank             Chicago
#  2                  The First National Bank of Lindsay             Lindsay
#  3               Republic First Bank dba Republic Bank        Philadelphia
#  4                                       Citizens Bank            Sac City
#  5                            Heartland Tri-State Bank             Elkhart
#  6                                 First Republic Bank       San Francisco
#  7                                      Signature Bank            New York
#  8                                 Silicon Valley Bank         Santa Clara
#  9                                   Almena State Bank              Almena
#  10                         First City Bank of Florida   Fort Walton Beach
# ...

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('my_table', engine)
# Out:
# 4

# %%
sqldf = pd.read_sql('my_table', con=engine) #con is connection

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %%
#Pandas isnt great for sql so use specific drivers for the particular sql server you use instead of pandas
